# %%
import sklearn
from sklearn import decomposition
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.title('data')
data = np.random.randn(5, 6)
plt.imshow(data)
plt.show()

# plt.title('components')
# pca = decomposition.PCA(n_components=3)
# pca.fit(data)
# plt.imshow(pca.components_)
# plt.show()

plt.title('transformed')
out = pca.transform(data)
plt.imshow(out)
plt.show()

plt.title('reconstruction')
recon = pca.inverse_transform(out)
plt.imshow(recon)
plt.show()

plt.title('err')
plt.imshow(recon - data)
plt.show()
