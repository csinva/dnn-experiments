# %%
import sigpy.plot as pl
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
# os.system("ls -l")
# %matplotlib notebook

# %%
for i in range(31):
    os.system("ffmpeg -i lena_gray_512.tif -q:v %s lena_output%s.jpg" % (str(i+1),str(i+1)))

# %%
def rmse(im_g,im_r):
    return np.sqrt(np.sum(((im_g-im_r)**2))/np.size(im_g))

# %%
rmses = []
bits = []
groundtruth = cv2.imread("lena_gray_512.tif",cv2.IMREAD_GRAYSCALE)
for i in range(31):
    dir1 = "image_output%s.jpg" %str(i+1)
    result = cv2.imread(dir1,cv2.IMREAD_GRAYSCALE)
    rmse_1 = rmse(result,groundtruth)
    bit = (os.path.getsize(dir1)*8)/(512*512)
    print(bit)
    rmses.append(rmse_1)
    bits.append(bit)
# Out:
# 1.642669677734375
# 1.642669677734375
# 1.156494140625
# 0.9110107421875
# 0.78448486328125
# 0.688018798828125
# 0.619537353515625
# 0.560211181640625
# 0.523406982421875
# 0.491851806640625
# 0.4632568359375
# 0.43939208984375
# 0.42181396484375
# 0.403167724609375
# 0.388214111328125
# 0.373687744140625
# 0.362274169921875
# 0.352142333984375
# 0.342193603515625
# 0.3328857421875
# 0.326385498046875
# 0.31903076171875
# 0.310516357421875
# 0.303802490234375
# 0.298248291015625
# 0.292755126953125
# 0.2872314453125
# 0.28277587890625
# 0.278167724609375
# 0.274078369140625
# 0.270263671875

# %%
plt.plot(rmses,bits);plt.title("Rate Distortion Performance")
plt.xlabel("Distortion")
plt.ylabel("Rate")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rmse(result,groundtruth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-080dfcfc75bf> in <module>()
# ----> 1 rmse(result,groundtruth)
#
# TypeError: 'numpy.float64' object is not callable

# %%
"lena_output%s.jpg" %str(i+1)
# Out:
# 'lena_output50.jpg'

# %%
groundtruth.shape
# Out:
# (512, 512)

# %%
b = os.path.getsize("lena_output1.jpg")
print(b)
# Out:
# 53827
